# %%
import trees
import treePlotter
# Out:
# [NbConvertApp] Converting notebook trees.ipynb to python
# [NbConvertApp] Writing 4616 bytes to trees.py
# [NbConvertApp] Converting notebook treePlotter.ipynb to python
# [NbConvertApp] Writing 3673 bytes to treePlotter.py

# %%
fr = open('lenses.txt')

# %%
lenses = [inst.strip().split('\t') for inst in fr.readlines()]

# %%
lensesLabels = ['age','prescript','astigmatic','tearRate']

# %%
lensesTree = trees.createTree(lenses,lensesLabels)

# %%
lensesTree
# Out:
# {'tearRate': {'normal': {'astigmatic': {'no': {'age': {'pre': 'soft',
#       'presbyopic': {'prescript': {'hyper': 'soft', 'myope': 'no lenses'}},
#       'young': 'soft'}},
#     'yes': {'prescript': {'hyper': {'age': {'pre': 'no lenses',
#         'presbyopic': 'no lenses',
#         'young': 'hard'}},
#       'myope': 'hard'}}}},
#   'reduced': 'no lenses'}}

# %%
treePlotter.createPlot(lensesTree)
